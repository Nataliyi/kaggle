# %%
from sklearn.datasets import fetch_20newsgroups

# %%
categories = ['alt.atheism', 
              'soc.religion.christian', 
              'comp.graphics',
              'sci.med']

# %%
twenty_train = fetch_20newsgroups(subset='train', categories=categories,
                                 shuffle=True, random_state=42)
# parametr shuffle shuffles(mixes) the sequence

# %%
twenty_train.data[0]
# Out:
# 'From: sd345@city.ac.uk (Michael Collier)\nSubject: Converting images to HP LaserJet III?\nNntp-Posting-Host: hampton\nOrganization: The City University\nLines: 14\n\nDoes anyone know of a good way (standard PC application/PD utility) to\nconvert tif/img/tga files into LaserJet III format.  We would also like to\ndo the same, converting to HPGL (HP plotter) files.\n\nPlease email any response.\n\nIs this the correct group?\n\nThanks in advance.  Michael.\n-- \nMichael Collier (Programmer)                 The Computer Unit,\nEmail: M.P.Collier@uk.ac.city                The City University,\nTel: 071 477-8000 x3769                      London,\nFax: 071 477-8565                            EC1V 0HB.\n'

# %%
len(twenty_train.data)
# Out:
# 2257

# %%
len(twenty_train.filenames)
# Out:
# 2257

# %%
print('\n'.join(twenty_train.data[0].split('\n')[:]))
# Out:
# From: sd345@city.ac.uk (Michael Collier)
# Subject: Converting images to HP LaserJet III?
# Nntp-Posting-Host: hampton
# Organization: The City University
# Lines: 14
#
# Does anyone know of a good way (standard PC application/PD utility) to
# convert tif/img/tga files into LaserJet III format.  We would also like to
# do the same, converting to HPGL (HP plotter) files.
#
# Please email any response.
#
# Is this the correct group?
#
# Thanks in advance.  Michael.
# --
# Michael Collier (Programmer)                 The Computer Unit,
# Email: M.P.Collier@uk.ac.city                The City University,
# Tel: 071 477-8000 x3769                      London,
# Fax: 071 477-8565                            EC1V 0HB.

# %%
twenty_train.target_names
# Out:
# ['alt.atheism', 'comp.graphics', 'sci.med', 'soc.religion.christian']

# %%
twenty_train.target
# Out:
# array([1, 1, 3, ..., 2, 2, 2])

# %%
for i in twenty_train.target:
    print(twenty_train.target_names[i])
# Out:
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# alt.atheism
# comp.graphics
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# soc.religion.christian
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# sci.med
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# alt.atheism
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# alt.atheism
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# alt.atheism
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# sci.med
# sci.med
# sci.med
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# alt.atheism
# alt.atheism
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# alt.atheism
# alt.atheism
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# alt.atheism
# alt.atheism
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# sci.med
# alt.atheism
# sci.med
# sci.med
# sci.med
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# alt.atheism
# sci.med
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# sci.med
# comp.graphics
# alt.atheism
# soc.religion.christian
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# comp.graphics
# alt.atheism
# soc.religion.christian
# alt.atheism
# alt.atheism
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# sci.med
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# alt.atheism
# sci.med
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# sci.med
# soc.religion.christian
# sci.med
# sci.med
# sci.med
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# sci.med
# sci.med
# sci.med
# sci.med
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# sci.med
# sci.med
# alt.atheism
# soc.religion.christian
# alt.atheism
# sci.med
# sci.med
# soc.religion.christian
# sci.med
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# sci.med
# alt.atheism
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# alt.atheism
# soc.religion.christian
# sci.med
# alt.atheism
# sci.med
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# comp.graphics
# comp.graphics
# soc.religion.christian
# comp.graphics
# comp.graphics
# alt.atheism
# alt.atheism
# comp.graphics
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# soc.religion.christian
# sci.med
# sci.med
# alt.atheism
# alt.atheism
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# comp.graphics
# sci.med
# soc.religion.christian
# comp.graphics
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# alt.atheism
# alt.atheism
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# alt.atheism
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# sci.med
# alt.atheism
# alt.atheism
# sci.med
# sci.med
# comp.graphics
# soc.religion.christian
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# comp.graphics
# alt.atheism
# alt.atheism
# soc.religion.christian
# soc.religion.christian
# alt.atheism
# comp.graphics
# alt.atheism
# alt.atheism
# sci.med
# comp.graphics
# alt.atheism
# sci.med
# sci.med
# sci.med
# comp.graphics
# comp.graphics
# sci.med
# sci.med
# sci.med
# soc.religion.christian
# soc.religion.christian
# comp.graphics
# soc.religion.christian
# alt.atheism
# sci.med
# sci.med
# sci.med
# sci.med
# sci.med
# sci.med

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
count_vect = CountVectorizer()

# %%
X_train_counts = count_vect.fit_transform(twenty_train.data)

# %%
X_train_counts.shape
# Out:
# (2257, 35788)

# %%
count_vect.vocabulary_.get(u'algorithm')
# Out:
# 4690

# %%
from sklearn.feature_extraction.text import TfidfTransformer

# %%
tfidf_transformer = TfidfTransformer()

# %%
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
clf = MultinomialNB().fit(X_train_tfidf, twenty_train.target)

# %%
docs_new = ['God is love', 'OpenGL on the GPU is fast']

# %%
X_new_counts = count_vect.transform(docs_new)

# %%
X_new_tfidf = tfidf_transformer.transform(X_new_counts)

# %%
predicted = clf.predict(X_new_tfidf)

# %%
for doc, category in zip(docs_new, predicted):
    print('%r => %s' % (doc, twenty_train.target_names[category]))
# Out:
# 'God is love' => soc.religion.christian
# 'OpenGL on the GPU is fast' => comp.graphics

# %%
from sklearn.pipeline import Pipeline

# %%
text_clf = Pipeline([('vect', CountVectorizer()),
                    ('tfidf', TfidfTransformer()),
                    ('clf', MultinomialNB())])

# %%
text_clf
# Out:
# Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', MultinomialNB())])

# %%
text_clf = text_clf.fit(twenty_train.data, twenty_train.target)

# %%
import numpy as np

# %%
twenty_test = fetch_20newsgroups(subset='test', categories=categories,
                                shuffle=True, random_state=42)

# %%
docs_test = twenty_test.data

# %%
predicted = text_clf.predict(docs_test)

# %%
np.mean(predicted == twenty_test.target)
# Out:
# 0.8348868175765646

# %%
predicted
# Out:
# array([2, 2, 3, ..., 2, 2, 1])

# %%
from sklearn.linear_model import SGDClassifier
text_clf = Pipeline([('vect', CountVectorizer()),
                    ('tfidf', TfidfTransformer()),
                    ('clf', SGDClassifier())])
text_clf = text_clf.fit(twenty_train.data, twenty_train.target)
predicted = text_clf.predict(docs_test)
np.mean(predicted == twenty_test.target)
# Out:
# 0.9287616511318242

# %%
from sklearn import metrics

# %%
metrics.classification_report(twenty_test.target, predicted, 
                              target_names=twenty_test.target_names)
# Out:
# '                        precision    recall  f1-score   support\n\n           alt.atheism       0.95      0.85      0.90       319\n         comp.graphics       0.91      0.97      0.94       389\n               sci.med       0.96      0.92      0.94       396\nsoc.religion.christian       0.90      0.96      0.93       398\n\n              accuracy                           0.93      1502\n             macro avg       0.93      0.92      0.93      1502\n          weighted avg       0.93      0.93      0.93      1502\n'

# %%
metrics.confusion_matrix(twenty_test.target, predicted)
# Out:
# array([[270,   7,   8,  34],
#        [  4, 377,   4,   4],
#        [  4,  23, 365,   4],
#        [  5,   7,   3, 383]])

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'vect_ngram_range': [(1, 1), (1, 2)],
            'tfidf_use_idf': (True, False),
             'clf__alpha': (1e-2, 1e-3),}

# %%
gs_clf = GridSearchCV(text_clf, parameters, n_jobs=-1)

# %%
gs_clf = gs_clf.fit(twenty_train.data[:400], twenty_train.target[:400])
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 431, in _process_worker
#     r = call_item()
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/joblib/externals/loky/process_executor.py", line 285, in __call__
#     return self.fn(*self.args, **self.kwargs)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py", line 595, in __call__
#     return self.func(*args, **kwargs)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/joblib/parallel.py", line 252, in __call__
#     return [func(*args, **kwargs)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/joblib/parallel.py", line 252, in <listcomp>
#     return [func(*args, **kwargs)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/sklearn/model_selection/_validation.py", line 520, in _fit_and_score
#     estimator = estimator.set_params(**cloned_parameters)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/sklearn/pipeline.py", line 141, in set_params
#     self._set_params('steps', **kwargs)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/sklearn/utils/metaestimators.py", line 53, in _set_params
#     super().set_params(**params)
#   File "/home/miss/kaggle/venv/lib/python3.8/site-packages/sklearn/base.py", line 249, in set_params
#     raise ValueError('Invalid parameter %s for estimator %s. '
# ValueError: Invalid parameter tfidf_use_idf for estimator Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', SGDClassifier())]). Check the list of available parameters with `estimator.get_params().keys()`.
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-07b39699eb10> in <module>
# ----> 1 gs_clf = gs_clf.fit(twenty_train.data[:400], twenty_train.target[:400])
#
# ~/kaggle/venv/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/kaggle/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
#     737
#     738         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# ~/kaggle/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1186     def _run_search(self, evaluate_candidates):
#    1187         """Search all candidates in param_grid"""
# -> 1188         evaluate_candidates(ParameterGrid(self.param_grid))
#    1189
#    1190
#
# ~/kaggle/venv/lib/python3.8/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     706                               n_splits, n_candidates, n_candidates * n_splits))
#     707
# --> 708                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     709                                                        X, y,
#     710                                                        train=train, test=test,
#
# ~/kaggle/venv/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1040
#    1041             with self._backend.retrieval_context():
# -> 1042                 self.retrieve()
#    1043             # Make sure that we get a last message telling us we are done
#    1044             elapsed_time = time.time() - self._start_time
#
# ~/kaggle/venv/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     919             try:
#     920                 if getattr(self._backend, 'supports_timeout', False):
# --> 921                     self._output.extend(job.get(timeout=self.timeout))
#     922                 else:
#     923                     self._output.extend(job.get())
#
# ~/kaggle/venv/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                 raise CancelledError()
#     438             elif self._state == FINISHED:
# --> 439                 return self.__get_result()
#     440             else:
#     441                 raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# ValueError: Invalid parameter tfidf_use_idf for estimator Pipeline(steps=[('vect', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('clf', SGDClassifier())]). Check the list of available parameters with `estimator.get_params().keys()`.

# %%
sorted(text_clf.get_params().keys())
